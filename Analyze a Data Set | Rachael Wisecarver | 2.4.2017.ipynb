# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # The following data describes housing values in Boston Suburbs.

# %% [markdown]
# ### Attribute Information:
#
# 1. CRIM: per capita crime rate by town
# 2. ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 3. INDUS: proportion of non-retail business acres per town
# 4. CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 5. NOX: nitric oxides concentration (parts per 10 million)
# 6. RM: average number of rooms per dwelling
# 7. AGE: proportion of owner-occupied units built prior to 1940
# 8. DIS: weighted distances to five Boston employment centres
# 9. RAD: index of accessibility to radial highways
# 10. TAX: full-value property-tax rate per \$10,000
# 11. PTRATIO: pupil-teacher ratio by town
# 12. B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT: Percent of lower status of the population
# 14. MEDV: Median value of owner-occupied homes in $1000's.

# %%
housing_data = pd.read_csv("boston_housing_data.csv",
                           names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'],
                           delim_whitespace=True,
                          )

# %%
housing_data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# ...

# %% [markdown]
# ## Finding the median and mean home value of all Boston suburbs:

# %%
median_value = housing_data.loc[:, "MEDV"]

# %%
mean_value_all_suburbs = median_value.mean() * 1000

# %%
median_value_all_suburbs = median_value.median() * 1000

# %%
mean_value_all_suburbs
# Out:
# 22532.806324110676

# %%
median_value_all_suburbs
# Out:
# 21200.0

# %% [markdown]
# ## Finding the median home value of the suburb with the youngest houses:

# %%
age = min(housing_data.loc[:, "AGE"])

# %%
youngest_town = housing_data.loc[housing_data['AGE'] == min(housing_data.loc[:, "AGE"])]

# %%
median_value_youngest_town = youngest_town.loc[:, "MEDV"].median()

# %%
median_value_youngest_town
# Out:
# 26.6

# %% [markdown]
# ## Mapping out the relationship between per-capita crime rate and the pupil-teacher ratio. Differentiate between whether or not the suburb is bounded by the Charles River.

# %%
river = [1]

# %%
on_river = housing_data[housing_data.CHAS.isin(river)]

# %%
plt.scatter(on_river.loc[:, "PTRATIO"], on_river.loc[:, "CRIM"])

# %%
plt.xlabel("Student Teacher Ratio")

# %%
plt.title("Relationship between student/teacher ratio and crime rate per capita, for properties on Charles River")

# %%
plt.show()

# %%
off_river = housing_data[~housing_data.CHAS.isin(river)]

# %%
plt.scatter(off_river.loc[:, "PTRATIO"], off_river.loc[:, "CRIM"])

# %%
plt.title("Relationship between student/teacher ratio and crime rate per capita, for properties *not* on Charles River")

# %%
plt.xlabel("Student Teacher Ratio")

# %%
plt.show()

# %% [markdown]
# ## Plotting the relationship between the proportion of black citizens and the distance to employment centers in Boston.

# %%
plt.scatter(housing_data.loc[:, "B"], housing_data.loc[:, "DIS"])

# %%
plt.title("Correlation between proportion of black citizens and distance to employment centers in Boston")

# %%
plt.xlabel("Proportion of Black Citizens")

# %%
plt.show()

# %% [markdown]
# ## Finding the relationship between median value of owner-occuped homes and nitric oxide concentration, along with median home value and the proportion of non-retail business.

# %%
plt.scatter(housing_data.loc[:, "MEDV"], housing_data.loc[:, "NOX"], c="orange")

# %%
plt.scatter(housing_data.loc[:, "MEDV"], housing_data.loc[:, "INDUS"], c="blue")

# %%
plt.xlabel("Median home value")

# %%
plt.title("Relationship between Value of Owner Occupied Homes, Nitric Oxide Concentration, and Proportion of Non-Retail Business")

# %%
plt.show()

# %% [markdown]
# ## What is the relationship between crime rate and proximity to industrial centers?

# %%
plt.scatter(housing_data.loc[:, "INDUS"], housing_data.loc[:, "CRIM"])

# %%
plt.xlabel("Proportion of Industrial Businesses")

# %%
plt.title("Relationship Between Crime Rates and Proportion of Non-Retail Business")

# %%
plt.show()
